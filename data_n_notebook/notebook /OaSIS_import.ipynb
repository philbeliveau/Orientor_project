# %% [markdown]
# # OaSIS Knowledge base
# https://open.canada.ca/data/dataset/eeb3e442-9f19-4d12-8b38-c488fe4f6e5e

# %% [raw]
# # Labels 2023
# url = 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=103d18f2-dbae-47ba-b15c-68877b21e968&limit=5&q=title:jones'
# # Lead Statement 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=d2ad2407-7105-4f5d-9bb1-83a8d67e6d61&limit=5&q=title:jones'
#
# # Workplaces Employers 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=d8187994-6197-4c01-83e3-69f41337b173&limit=5&q=title:jones'
#
# # Example Titles 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=fb173460-13ce-4f76-a06c-294bd74fd0af&limit=5&q=title:jones'
#
# # Main Duties 2023
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=51f69e32-4a70-4771-a33e-972dd1fdfd16&limit=5&q=title:jones'
#
# # Employment Requirements 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=889d37bb-4377-4a54-82a4-a76e1a05103d&limit=5&q=title:jones'
#
# #  Additional Information 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=ccffcef6-f3b1-4026-ba19-f502d077246f&limit=5&q=title:jones'
#
# # Exclusions 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=d8d079ce-7a37-446b-adca-1237e15c362f&limit=5&q=title:jones'
#
# # Guide 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=9dd7858f-4e7f-4a62-b0ea-4327fde45a30&limit=5&q=title:jones'
#
# # Skills 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=cc38de47-b7d6-4282-b967-d4cb12474f07&limit=5&q=title:jones'
#
# # Abilities 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=01bc4d5b-b0e2-4e3d-ab61-f1f70e817293&limit=5&q=title:jones'
#
# # Personal Attributes 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=02895126-4eb2-430d-b780-ef74cc0a3332&limit=5&q=title:jones'
#
# # Knowledges 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=4ff79fb8-b858-466b-9806-bf7fba2b9b12&limit=5&q=title:jones'
#
# # Interests 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=bc6c40c7-1ec4-47ec-a0ad-53df2fe7f9ad&limit=5&q=title:jones'
#
# # Work Activities 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=f551127e-3ca6-4f04-8523-28a92d6dbdd2&limit=5&q=title:jones'
#
# # Work Context 2023 v1.0
# 'https://open.canada.ca/data/api/3/action/datastore_search?resource_id=0bb3613f-436b-4d42-8f88-78defd9208fd&limit=5&q=title:jones'

# %%
import os
import glob
import pandas as pd
from functools import reduce

folder_path = "/Users/philippebeliveau/Desktop/Notebook/Orientor_project/Orientor_project/data_n_notebook/data/OaSIS-selection"
knowledge_path = "/Users/philippebeliveau/Desktop/Notebook/Orientor_project/Orientor_project/data_n_notebook/data/KnowlegdeBase"
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

def load_and_standardize(filepath):
    """
    Reads a CSV, renames 'OaSIS profile code' or 'OaSIS Code - Final' to 'oasis_code',
    then groups all rows by oasis_code using appropriate aggregation.
    """
    df = pd.read_csv(filepath)
    possible_cols = {"OaSIS profile code", "OaSIS Code - Final"}
    found_cols = set(df.columns).intersection(possible_cols)

    if not found_cols:
        print(f"[SKIP] No recognized code column in {filepath}")
        return None, os.path.basename(filepath)

    old_col = list(found_cols)[0]
    df.rename(columns={old_col: "oasis_code"}, inplace=True)

    # Remove duplicate columns (e.g., if Label is repeated across datasets)
    df = df.loc[:, ~df.columns.duplicated()]

    # Group by oasis_code
    def aggregate_column(series):
        if pd.api.types.is_numeric_dtype(series):
            return series.mean()
        else:
            return " | ".join(series.dropna().astype(str).unique())

    grouped = df.groupby("oasis_code").agg(aggregate_column).reset_index()
    return grouped, os.path.basename(filepath)

def safe_merge(left_df, right_df, right_name):
    try:
        merged = pd.merge(left_df, right_df, on="oasis_code", how="outer")
        return merged
    except Exception as e:
        print(f"[MERGE ERROR] Could not merge with '{right_name}': {e}")
        return left_df

# Load and unify
df_list = []
name_list = []

for f in csv_files:
    df, name = load_and_standardize(f)
    if df is not None:
        df_list.append(df)
        name_list.append(name)

# Sequentially merge
if not df_list:
    print("No DataFrames to merge.")
else:
    combined_df = df_list[0]
    for i in range(1, len(df_list)):
        combined_df = safe_merge(combined_df, df_list[i], name_list[i])

    print("\n✅ Final merged shape:", combined_df.shape)
    print(combined_df.head())

    # Save final CSV
    os.makedirs(knowledge_path, exist_ok=True)
    output_csv = os.path.join(knowledge_path, "KnowledgeBase.csv")
    combined_df.to_csv(output_csv, index=False)
    print(f"📁 Saved unified dataset to: {output_csv}")
# Out:
# ✅ Final merged shape: (900, 55)
#    oasis_code                              OaSIS Label - Final_x  \
# 0        10.0                                        Legislators
# 1        11.0           Senior government managers and officials
# 2        12.0  Senior managers - financial, communications an...
# 3        13.0  Senior managers - health, education, social an...
# 4        14.0  Senior managers - trade, broadcasting and othe...
#
#     Active Learning   Adaptability  Analytical Thinking  Attention to Detail  \
# 0               4.0            5.0                  5.0                  5.0
# 1               4.0            4.0                  5.0                  5.0
# 2               4.0            4.0                  5.0                  5.0
# 3               5.0            4.0                  5.0                  5.0
# 4               4.0            4.0                  5.0                  5.0
#
#     Creativity  Concern for Others  Collaboration   Independence  ...  \
# 0          4.0                 5.0            5.0            5.0  ...
# 1          4.0                 4.0            5.0            5.0  ...
# 2          4.0                 4.0            5.0            5.0  ...
# 3          4.0                 4.0            5.0            5.0  ...
# 4          4.0                 4.0            5.0            5.0  ...
#
#    Management of Personnel Resources  Monitoring  Time Management  \
# 0                                5.0         5.0              5.0
# 1                                5.0         5.0              5.0
# 2                                5.0         5.0              5.0
# 3                                5.0         5.0              5.0
# 4                                5.0         5.0              5.0
#
#    Coordinating  Instructing  Negotiating Persuading Social Perceptiveness  \
# 0           5.0          4.0          5.0        5.0                   5.0
# 1           5.0          4.0          5.0        5.0                   4.0
# 2           5.0          4.0          5.0        5.0                   4.0
# 3           5.0          4.0          5.0        5.0                   4.0
# 4           5.0          4.0          5.0        5.0                   4.0
#
#                                                Label  \
# 0                                        Legislators
# 1           Senior government managers and officials
# 2  Senior managers - financial, communications an...
# 3  Senior managers - health, education, social an...
# 4  Senior managers - trade, broadcasting and othe...
#
#                               Employment requirement
# 0  Election to a legislative body, or appointment...
# 1  A university degree or college diploma is usua...
# 2  A university degree in business administration...
# 3  A university degree or college diploma in busi...
# 4  A university degree or college diploma in busi...
#
# [5 rows x 55 columns]
# 📁 Saved unified dataset to: /Users/philippebeliveau/Desktop/Notebook/Orientor_project/Orientor_project/data_n_notebook/data/KnowlegdeBase/KnowledgeBase.csv

# %%
group = combined_df['OaSIS Label - Final'].unique()
# print(combined_df['OaSIS Label - Final'].nunique())

# Show me the Legislators, main duties by expanding the text so that I can see all of it
combined_df[combined_df['OaSIS Label - Final']=='Legislators']['Main duties'].str.split(',').explode().unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/orientor/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OaSIS Label - Final'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 group = combined_df['OaSIS Label - Final'].unique()
#       2 # print(combined_df['OaSIS Label - Final'].nunique())
#       3
#       4 # Show me the Legislators, main duties by expanding the text so that I can see all of it
#       5 combined_df[combined_df['OaSIS Label - Final']=='Legislators']['Main duties'].str.split(',').explode().unique()
#
# File ~/miniforge3/envs/orientor/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/miniforge3/envs/orientor/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'OaSIS Label - Final'

# %%
# Show me the columns (all of them) there is to
combined_df.columns
# Out:
# Index(['oasis_code', 'OaSIS Label - Final_x', ' Active Learning',
#        ' Adaptability', 'Analytical Thinking', 'Attention to Detail',
#        ' Creativity', 'Concern for Others', 'Collaboration', ' Independence',
#        'Innovativeness', 'Leadership', 'Social Orientation',
#        'Service Orientation', 'Stress Tolerance', 'Concordance number',
#        'Job title type', 'Job title text', 'Main duties',
#        'OaSIS Label - Final_y', 'Reading Comprehension', 'Writing  ',
#        'Numeracy ', ' Digital Literacy',
#        'Oral Communication: Active Listening   ',
#        'Oral Communication: Oral Comprehension   ',
#        'Oral Communication: Oral Expression ', 'Critical Thinking',
#        'Decision Making', 'Evaluation', 'Learning and Teaching Strategies',
#        'Problem Solving', 'Systems Analysis', 'Digital Production',
#        'Preventative Maintenance', 'Equipment and Tool Selection',
#        'Operation and Control',
#        'Operation Monitoring of Machinery and Equipment',
#        'Quality Control Testing', 'Repairing', 'Setting up', 'Product Design',
#        'Troubleshooting', 'Management of Financial Resources',
#        'Management of Material Resources', 'Management of Personnel Resources',
#        'Monitoring', 'Time Management', 'Coordinating', 'Instructing',
#        'Negotiating', 'Persuading', 'Social Perceptiveness', 'Label',
#        'Employment requirement'],
#       dtype='object')

# %%
# import os
# import csv
# from dotenv import load_dotenv
# from typing import Dict

# # Load .env just in case, though not needed here
# load_dotenv()

# CSV_PATH = "/Users/philippebeliveau/Desktop/Notebook/Orientor_project/Orientor_project/data_n_notebook/data/KnowledgeBase/KnowledgeBase.csv"

# def combine_row_text(row: Dict[str, str]) -> str:
#     """Combine relevant columns into a single text string."""
#     text_parts = []

#     if row.get("Label"):
#         text_parts.append(f"Occupation: {row['Label']}")
#     if row.get("Lead statement"):
#         text_parts.append(f"Description: {row['Lead statement']}")
#     if row.get("Main duties"):
#         text_parts.append(f"Main duties: {row['Main duties']}")

#     for skill in ["Creativity", "Leadership", "Digital Literacy", "Critical Thinking", "Problem Solving"]:
#         if row.get(skill):
#             text_parts.append(f"{skill}: {row[skill]}")

#     return ". ".join(text_parts).strip()

# # Read the CSV and preview the first few combined texts
# try:
#     with open(CSV_PATH, "r", encoding="utf-8") as f:
#         reader = csv.DictReader(f)

#         for i, row in enumerate(reader):
#             if not row or not row.get("oasis_code"):
#                 continue  # skip invalid
#             text = combine_row_text(row)
#             print(f"--- Row {i} ---")
#             print(text)
#             print()

#             if i >= 4:  # just preview the first 5 rows
#                 break

# except Exception as e:
#     print(f"Error reading CSV: {e}")
